# %%
# Here I'm just using this to import the relevant packages, not actually using any of the functions in this file
#from crossmatch_fns import *
import pandas as pd
import numpy as np
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from astropy import units as u
import matplotlib.pyplot as plt

# %%
semesters_folder_path = '/hildafs/projects/phy220048p/leihu/AstroWork/DESIRT/IMPROC/trigger/MESS/FinalList'

# %%
path_to_21A_beta_summ = f'{semesters_folder_path}/LYSelection-21A-beta.csv'
path_to_21A_summ = f'{semesters_folder_path}/LYSelection-21A.csv'

# %%
df_21A_beta = pd.read_csv(path_to_21A_beta_summ).dropna()
df_21A = pd.read_csv(path_to_21A_summ).dropna()

# %%
path_to_21A_summ = f'{semesters_folder_path}/LYSelection-21A-beta.CandidateSummary_RefinedDLR.csv'

# %%
df_21A_beta_read = pd.read_csv(path_to_21A_summ)

# %%
df_21A_beta_read
# Out:
#                        objid      ra_obj   dec_obj  \
# 0    A202103221418494m013843  214.705784 -1.645215
# 1    A202104091450185p015447  222.576999  1.913129
# 2    C202106021441403p004146  220.417762  0.696157
# 3    A202103221444062m031207  221.025889 -3.201883
# 4    A202103221431439m035616  217.933030 -3.937856
# ..                       ...         ...       ...
# 202  C202106051413541p020722  213.475318  2.122693
# 203  C202104061443253p005944  220.855220  0.995469
# 204  T202106021449003p003226  222.251302  0.540516
# 205  C202106021408492p010651  212.204872  1.114254
# 206  C202104271201577p004000  180.490587  0.666694
#
#                        DLR_type     DLR_d lsdr10_id.pseudo_host  \
# 0       Nearest_GoodSmallestDLR  0.377054        2146m017_13151
# 1       Nearest_GoodSmallestDLR  1.301945         2226p020_4195
# 2     NotNearest_BadSmallestDLR  8.338212         2203p007_9776
# 3       Nearest_GoodSmallestDLR  0.275725         2209m032_9676
# ...
