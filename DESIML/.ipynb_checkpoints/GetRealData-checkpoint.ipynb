# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from glob import glob
from matplotlib.backends.backend_pdf import PdfPages
from astropy import units as u
from astropy.coordinates import SkyCoord
#pd.options.mode.copy_on_write = True
from astropy.table import Table
from astropy.cosmology import FlatLambdaCDM
import multiprocessing as mp
from tqdm import tqdm
cosmo = FlatLambdaCDM(name='Planck18', H0=67.66, Om0=0.30966, Tcmb0=2.7255, Neff=3.046, m_nu=[0.  , 0.  , 0.06]* u.eV, Ob0=0.04897)
cores = 8
plt.style.use('ggplot')
from collections import Counter

# %%
from desispec.io import read_spectra
from desitrip.preproc import rebin_flux, rescale_flux

from glob import glob

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', message='.*read_spectra.*')

# %%
minw, maxw, nbins = 3000., 8000., 150

# %%
def drop_nan(mytable):
    has_nan = np.zeros(len(mytable), dtype=bool)
    for col in mytable.itercols():
        if col.info.dtype.kind == 'f':
            has_nan |= np.isnan(col)
    mytable_no_nan = mytable[~has_nan]
    return mytable_no_nan

# %%
def condition_tde(coadd_files):
    """Read DESI spectra, rebin to a subsampled logarithmic wavelength grid, and rescale.
    
    Parameters
    ----------
    coadd_files : list or ndarray
        List of ascii files
    
    Returns
    -------
    fluxes : ndarray
        Array of fluxes rebinned to a logarithmic wavelength grid.
    """
    fluxes = []
    
    for i in coadd_files:
        cf = i[0]
        z = i[1]
        try:
            which = len(Table.read(cf, format = "ascii").colnames)
        except:
            print(cf)
            continue
        if(which == 3):
            spectra = drop_nan(Table.read(cf, format = "ascii", names = ["wave", "flux", "flux_err"]))
            wave = spectra["wave"]
            flux = spectra["flux"]
            ivar = spectra["flux_err"]
        elif(which == 6):
            spectra = drop_nan(Table.read(cf, format = "ascii", names = ["wave", "flux", "sky_flux", "flux_err", "xpixel", "ypixel", "resopnse"]))
            wave = spectra["wave"]
            flux = spectra["flux"]
            ivar = spectra["flux_err"]
        elif(which == 2):
            spectra = drop_nan(Table.read(cf, format = "ascii", names = ["wave", "flux"]))
            wave = spectra["wave"]
            flux = spectra["flux"]
            ivar = None

#         # Pre-condition: remove spectra with NaNs and zero flux values.
#         mask = np.isnan(flux).any(axis=1) | (np.count_nonzero(flux, axis=1) == 0)
#         mask_idx = np.argwhere(mask)
#         flux = np.delete(flux, mask_idx, axis=0)
#         ivar = np.delete(ivar, mask_idx, axis=0)

        # Rebin and rescale fluxes so that each is normalized between 0 and 1.
        #spectra_table = Table()
        #spectra_table["wave"] = wave
        #spectra_table["flux"] = flux
        
        try:
            rewave, reflux, reivar = rebin_flux(wave / (z + 1), flux, ivar, minwave=minw, maxwave=maxw, nbins=nbins, log=True, clip=True)
        except:
            print(wave)
        rsflux = rescale_flux(reflux)
        if(np.sum(np.isnan(rsflux)) == 0):
            fluxes.append(rsflux)
    return fluxes

# %%
tde_files = sorted(glob("TDE_Spectra/*.ascii"))
#tde_flux = np.asarray(condition_tde(tde_files))
#tde_flux.shape

# %%
all_ztf_i = Table.read("ztf_spectra/SEDM_ML_sample.ascii", format = "ascii")
all_ztf_i.rename_column('col1', 'ZTF_Name')
all_ztf_i.rename_column('col2', "Class")
all_ztf_i.rename_column('col3', "z")
all_ztf_i.rename_column('col8', "Version")

# %%
all_ztf_i_important = all_ztf_i["ZTF_Name", "Class", "z", "Version"]

# %%
usable = all_ztf_i_important[np.where((all_ztf_i_important["Class"] != "NaN") & (all_ztf_i_important["Class"] != "-") & (np.logical_not(np.isnan(all_ztf_i_important["z"]))))]

# %%
plt.hist(usable["z"], bins = 100)
# Out:
# (array([2.980e+02, 8.730e+02, 1.479e+03, 1.762e+03, 1.234e+03, 8.680e+02,
#         8.790e+02, 7.080e+02, 5.300e+02, 2.820e+02, 1.200e+02, 9.700e+01,
#         7.800e+01, 1.700e+01, 2.200e+01, 3.600e+01, 3.000e+00, 1.500e+01,
#         8.000e+00, 5.000e+00, 3.200e+01, 1.900e+01, 7.000e+00, 4.000e+00,
#         2.900e+01, 2.500e+01, 1.100e+01, 0.000e+00, 1.200e+01, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.300e+01, 0.000e+00, 2.000e+00, 8.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
Counter(usable["Class"])
# Out:
# Counter({'Ia': 4014,
#          'II': 1876,
#          'Ic': 509,
#          'Ib': 391,
#          'IIn': 328,
#          'SLSN-I': 274,
#          'IIb': 251,
#          'Ic-BL': 234,
#          'TDE': 177,
#          'IIP': 175,
#          'Ia-91T': 160,
#          'SLSN-II': 134,
#          'AGN': 113,
#          'Ibn': 92,
#          'Iax': 60,
#          'Icn': 59,
#          'Ia-91bg': 48,
#          'Ib/c': 40,
#          'Ia-pec': 40,
#          'SLSN-I.5': 37,
#          'nova': 30,
#          'Ia-CSM': 29,
#          'AGN?': 24,
#          'II?': 24,
#          'CLAGN': 23,
#          'Ia-02cx': 23,
#          'ILRT': 23,
#          'LBV': 22,
#          'CV': 21,
#          'NLSy1?': 21,
#          'NLS1': 17,
#          'SLSN-I?': 17,
#          'Ca-rich': 15,
#          'GapI-Ca-rich': 15,
#          'Ia?': 14,
#          'Ia-CSM?': 13,
#          'Ic?': 12,
#          'II-87A': 10,
#          'Ic-pec': 10,
#          'Ib-pec': 10,
#          'Q': 9,
# ...

# %%
classes_of_interest = ["TDE", "Ia", "II", "Ic", "Ib", "AGN", "galaxy", "NLS", "QSO"]
# "FBOT", "CV", "AGN", "ILRT", "LBV"

# %%
tde_files = usable[np.where(classes_of_interest[0] in usable["Class"])]
tde_flux = np.asarray(condition_tde(tde_files))
# Out:
# ZTF18aabssth

# %%
def get_indicies(c, data):
    counter = 0
    idx = []
    for i in range(len(data)):
        if(c in data[i]):
            idx.append(counter)
        counter += 1
    return idx

# %%
classes_of_interest_dict = {}
for c in classes_of_interest:
    classes_of_interest_dict[c] = get_indicies(c, usable["Class"])

# %%
tde_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["TDE"]]]
tde_flux = np.asarray(condition_tde(tde_files))
tde_flux.shape
# Out:
# (168, 150)

# %%
gal_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["galaxy"]]]
gal_flux = np.asarray(condition_tde(gal_files))
gal_flux.shape
# Out:
# (2, 150)

# %%
nls_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["NLS"]]]
nls_flux = np.asarray(condition_tde(nls_files))
np.save("ztf_spectra/nls_flux", nls_flux)
nls_flux.shape
# Out:
# (38, 150)

# %%
qso_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["QSO"]]]
qso_flux = np.asarray(condition_tde(qso_files))
np.save("ztf_spectra/qso_flux", qso_flux)
qso_flux.shape
# Out:
# (1, 150)

# %%
snia_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["Ia"]]]
snia_flux = np.asarray(condition_tde(snia_files))
snia_flux.shape
# Out:
# (4406, 150)

# %%
snii_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["II"]]]
snii_flux = np.asarray(condition_tde(snii_files))
snii_flux.shape
# Out:
# ztf_spectra/spectra/ZTF18abcfdzu_20181229_NOT_v1.ascii
# ztf_spectra/spectra/ZTF18acbwaxk_20190110_NOT_v1.ascii
# wave
# ----
# ztf_spectra/spectra/ZTF20aaynrrh_20200517_Lick_3-m_v2.ascii
# ztf_spectra/spectra/ZTF20aaynrrh_20200517_Lick_3-m_v3.ascii
# (2796, 150)

# %%
snib_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["Ib"]]]
snib_flux = np.asarray(condition_tde(snib_files))
snib_flux.shape
# Out:
# ztf_spectra/spectra/ZTF19aapfmki_20190511_NOT_v1.ascii
# wave
# ----
# ztf_spectra/spectra/ZTF19abucwzt_20200127_NOT_v1.ascii
# wave
# ----
# ztf_spectra/spectra/ZTF20aalrqbu_20200506_NOT_v1.ascii
# (779, 150)

# %%
snic_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["Ic"]]]
snic_flux = np.asarray(condition_tde(snic_files))
snic_flux.shape
# Out:
# ztf_spectra/spectra/ZTF18aceqrrs_20190227_NOT_v1.ascii
# ztf_spectra/spectra/ZTF18acsjrbc_20190102_NOT_v1.ascii
# ztf_spectra/spectra/ZTF19aafmyow_20190816_NOT_v1.ascii
# ztf_spectra/spectra/ZTF19abdoior_20190815_NOT_v1.ascii
# ztf_spectra/spectra/ZTF20aaelulu_20200114_NOT_v1.ascii
# (810, 150)

# %%
agn_files = [["ztf_spectra/spectra/{}".format(i["Version"]), i["z"]] for i in usable[classes_of_interest_dict["AGN"]]]
agn_flux = np.asarray(condition_tde(agn_files))
agn_flux.shape
# Out:
# (159, 150)

# %%
np.save("ztf_spectra/tde_flux", tde_flux)
np.save("ztf_spectra/snia_flux", snia_flux)
np.save("ztf_spectra/snii_flux", snii_flux)
np.save("ztf_spectra/snib_flux", snib_flux)
np.save("ztf_spectra/snic_flux", snic_flux)
np.save("ztf_spectra/agn_flux", agn_flux)
np.save("ztf_spectra/gal_flux", gal_flux)

# %%
fig, axes = plt.subplots(2,3, figsize=(14,11), sharex=True, sharey=True)
axes = axes.flatten()

for i in range(0,56):
    
    ax = axes[0]
    ax.plot(tde_flux[i], alpha=0.2)

    ax = axes[1]
    ax.plot(snia_flux[i], alpha=0.2)
    
    ax = axes[2]
    ax.plot(snii_flux[i], alpha=0.2)
    
    ax = axes[3]
    ax.plot(snib_flux[i], alpha=0.2)
    
    ax = axes[4]
    ax.plot(snic_flux[i], alpha=0.2)
    
    ax = axes[5]
    ax.plot(agn_flux[i], alpha=0.2)
    
axes[0].set_title('TDE spectra')
axes[1].set_title('SN Ia spectra')
axes[2].set_title('SN II spectra')
axes[3].set_title('SN Ib spectra')
axes[4].set_title('SN Ic spectra')
axes[5].set_title('AGN spectra')
fig.tight_layout()
