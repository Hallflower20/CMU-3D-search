# %%
from glob import glob

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tensorflow
from joblib import Parallel, delayed

import os
import shutil
import platform

import tensorflow as tf
from tensorflow.keras import utils, regularizers, callbacks, backend
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding1D, BatchNormalization, Flatten, Reshape, Conv1D, MaxPooling1D, Dropout, Add, LSTM, Embedding
from tensorflow.keras.initializers import glorot_normal, glorot_uniform
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from keras.callbacks import Callback, ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.metrics import confusion_matrix

mpl.rc('font', size=14)
# Out:
# 2024-11-21 10:42:46.984675: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-21 10:42:46.984699: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-21 10:42:46.985714: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 10:42:46.991855: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-21 10:42:50.626493: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, MaxPooling1D, Flatten, Dense, Dropout, Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import GlobalAveragePooling1D

# %%
def network(input_shape, ncat, learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1):
    """Define the CNN structure.
    
    Parameters
    ----------
    input_shape : int
        Shape of the input spectra.
    ncat : int
        Number of categories.
    learning_rate : float
        Learning rate.
    reg : float
        Regularization factor.
    dropout : float
        Dropout rate.
    seed : int
        Seed of initializer.
    
    Returns
    -------
    model : tensorflow.keras.Model
        A model instance of the network.
    """
    X_input = Input(input_shape, name='Input_Spec')

    # First convolutional layer.
    with backend.name_scope('Conv_1'):
        X = Conv1D(filters=8, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X_input)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size= 2)(X)

    # Second convolutional layer.
    with backend.name_scope('Conv_2'):
        X = Conv1D(filters=16, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Third convolutional layer.
    with backend.name_scope('Conv_3'):
        X = Conv1D(filters=32, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)
        
    # Fourth convolutional layer.
    with backend.name_scope('Conv_4'):
        X = Conv1D(filters=64, kernel_size=5, strides=1, padding='same',
                   kernel_regularizer=regularizers.l1(reg),
                   bias_initializer='zeros',
                   kernel_initializer=glorot_normal(seed))(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(2)(X)

    # Flatten to fully connected dense layer.
    with backend.name_scope('Dense_Layer'):
        X = Flatten()(X)
        X = Dense(256, kernel_regularizer=regularizers.l2(reg),
                  activation='relu')(X)
        X = Dropout(rate=dropout, seed=seed)(X)
    
    # Output layer with sigmoid activation.
    with backend.name_scope('Output_Layer'):
        X = Dense(ncat, kernel_regularizer=regularizers.l2(reg),
              activation='softmax',name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='SNnet')
    
    # Set up optimizer, loss function, and optimization metrics.
    model.compile(optimizer=Adam(lr=learning_rate), loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
def network_new(input_shape, ncat, learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1):
    """Define the CNN structure with improvements.

    Parameters
    ----------
    input_shape : int
        Shape of the input spectra.
    ncat : int
        Number of categories.
    learning_rate : float
        Learning rate.
    reg : float
        Regularization factor.
    dropout : float
        Dropout rate.
    seed : int
        Seed of initializer.

    Returns
    -------
    model : tensorflow.keras.Model
        A model instance of the network.
    """
    X_input = Input(input_shape, name='Input_Spec')
    initializer = HeNormal(seed=seed)

    def conv_block(X, filters, kernel_size=5, reg=0.0032):
        # Shortcut (residual connection) path
        X_shortcut = X

        # Main path
        X = Conv1D(filters=filters, kernel_size=kernel_size, strides=1, padding='same',
                   kernel_regularizer=l1(reg),
                   kernel_initializer=initializer)(X)
        X = BatchNormalization(axis=2)(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size=2)(X)

        # Adjust the shortcut path to match the dimensions of the main path
        X_shortcut = Conv1D(filters, kernel_size=1, padding='same')(X_shortcut)
        X_shortcut = MaxPooling1D(pool_size=2)(X_shortcut)  # Add pooling to the shortcut as well

        # Add the main path and shortcut
        X = Add()([X, X_shortcut])
        return X

    # Convolutional layers with residual connections
    X = conv_block(X_input, filters=16)
    X = conv_block(X, filters=32)
    X = conv_block(X, filters=64)
    X = conv_block(X, filters=128)

    # Flatten to fully connected dense layer.
    X = Flatten()(X)
    X = Dense(512, kernel_regularizer=l2(reg), activation='relu')(X)
    X = Dropout(rate=dropout)(X)
    X = Dense(256, kernel_regularizer=l2(reg), activation='relu')(X)
    X = Dropout(rate=dropout)(X)
    
    # Output layer with softmax activation.
    X = Dense(ncat, kernel_regularizer=l2(reg), activation='softmax', name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='Enhanced_SNnet')
    
    # Set up optimizer with learning rate scheduler
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
def network_one(input_shape, ncat, learning_rate=0.00021544346900318823, reg=0.0032, dropout=0.1, seed=1):
    """
    Define and compile a CNN with residual connections and enhancements.

    Parameters
    ----------
    input_shape : tuple
        Shape of the input data (e.g., (time_steps, channels)).
    ncat : int
        Number of output categories/classes.
    learning_rate : float
        Initial learning rate for the optimizer.
    reg : float
        Regularization factor for weight decay.
    dropout : float
        Dropout rate between dense layers.
    seed : int
        Seed for random number generators for reproducibility.

    Returns
    -------
    model : tensorflow.keras.Model
        Compiled Keras model ready for training.
    """

    np.random.seed(seed)
    tf.random.set_seed(seed)
    initializer = HeNormal(seed=seed)

    X_input = Input(shape=input_shape, name='Input_Spec')

    def conv_block(X, filters, kernel_size=5, pool_size=2, reg=0.0032):
        """
        Residual convolutional block with optional regularization and pooling.
        """
        X_shortcut = X

        # Main path
        X = Conv1D(filters=filters, kernel_size=kernel_size, strides=1, padding='same',
                   kernel_regularizer=l2(reg), kernel_initializer=initializer)(X)
        X = BatchNormalization()(X)
        X = Activation('relu')(X)
        X = MaxPooling1D(pool_size=pool_size)(X)

        # Shortcut path
        X_shortcut = Conv1D(filters=filters, kernel_size=1, strides=1, padding='same',
                            kernel_initializer=initializer)(X_shortcut)
        X_shortcut = MaxPooling1D(pool_size=pool_size)(X_shortcut)

        # Add the main path and the shortcut path
        X = Add()([X, X_shortcut])
        return X

    # Convolutional layers with residual connections
    X = conv_block(X_input, filters=32)
    X = conv_block(X, filters=64)
    X = conv_block(X, filters=128)
    X = conv_block(X, filters=256)

    # Global Average Pooling
    X = GlobalAveragePooling1D()(X)

    # Fully connected layers
    X = Dense(512, kernel_regularizer=l2(reg), activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dropout(rate=dropout)(X)
    X = Dense(256, kernel_regularizer=l2(reg), activation='relu')(X)
    X = BatchNormalization()(X)
    X = Dropout(rate=dropout)(X)

    # Output layer
    X = Dense(ncat, activation='softmax', name='Output_Classes')(X)

    model = Model(inputs=X_input, outputs=X, name='Enhanced_SNnet')

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
galaxy_flux_desi = np.load("DESI_spectra/galaxy_flux.npy")
snia_flux_desi = np.load("DESI_spectra/snia_flux.npy")
snib_flux_desi = np.load("DESI_spectra/snib_flux.npy")
snibc_flux_desi = np.load("DESI_spectra/snibc_flux.npy")
snic_flux_desi = np.load("DESI_spectra/snic_flux.npy")
sniin_flux_desi = np.load("DESI_spectra/sniin_flux.npy")
sniilp_flux_desi = np.load("DESI_spectra/sniilp_flux.npy")
sniip_flux_desi = np.load("DESI_spectra/sniip_flux.npy")
kn_flux = np.load("DESI_spectra/kn_flux.npy")

# %%
tde_flux_ztf = np.load("ztf_spectra/tde_flux.npy")
tde_flux_paper = np.load("tde_flux_1.npy")
snia_flux_ztf = np.load("ztf_spectra/snia_flux.npy")
snii_flux_ztf = np.load("ztf_spectra/snii_flux.npy")
snib_flux_ztf = np.load("ztf_spectra/snib_flux.npy")
snic_flux_ztf = np.load("ztf_spectra/snic_flux.npy")
galaxy_flux_ztf = np.load("ztf_spectra/gal_flux.npy")
agn_flux = np.load("ztf_spectra/agn_flux.npy")
nls_flux = np.load("ztf_spectra/nls_flux.npy")
qso_flux = np.load("ztf_spectra/qso_flux.npy")

# %%
snia_flux = np.vstack([snia_flux_desi, snia_flux_ztf])
snibc_flux = np.vstack([snib_flux_desi, snib_flux_ztf, snibc_flux_desi, snic_flux_ztf, snic_flux_desi])
snii_flux = np.vstack([sniin_flux_desi, snii_flux_ztf, sniin_flux_desi, sniilp_flux_desi, sniip_flux_desi])
galaxy_flux = np.vstack([galaxy_flux_desi, galaxy_flux_ztf, agn_flux, nls_flux, qso_flux])
tde_flux = np.vstack([tde_flux_ztf, tde_flux_paper])

# %%
minw, maxw, nbins = 3000., 8000., 150

# %%
ngalaxy, nbins  = galaxy_flux.shape
nsnia, nbins  = snia_flux.shape
nsnibc, nbins = snibc_flux.shape
nsnii, nbins = snii_flux.shape
ntde, nbins = tde_flux.shape
nkn, nbins = kn_flux.shape
ngalaxy, nsnia, nsnibc, nsnii, ntde, nkn, nbins
# Out:
# (10169, 14370, 29787, 42604, 224, 8947, 150)

# %%
x = np.concatenate([galaxy_flux, 
                    snia_flux,
                    snibc_flux,
                    snii_flux,
                    tde_flux,
                    kn_flux
                   ]).reshape(-1, nbins, 1)

labels = ['Galaxy',
          'SN Ia',
          'SN Ib/c',
          'SN II',
          'TDE',
          'KN']
ntypes = len(labels)

# Convert y-label array to appropriate categorical array
from tensorflow.keras.utils import to_categorical

y = to_categorical(
        np.concatenate([np.full(ngalaxy, 0), 
                        np.full(nsnia, 1),
                        np.full(nsnibc, 2),
                        np.full(nsnii, 3),
                        np.full(ntde, 4),
                        np.full(nkn, 5)
                       ]))

# %%
dropout = 0.5
model = network_new((nbins, 1), ncat=y.shape[1], dropout = dropout)
model.summary()
# Out:
# 2024-11-21 10:43:16.026201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38379 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# Model: "Enhanced_SNnet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Input_Spec (InputLayer)     [(None, 150, 1)]             0         []
#
#  conv1d (Conv1D)             (None, 150, 16)              96        ['Input_Spec[0][0]']
#
#  batch_normalization (Batch  (None, 150, 16)              64        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 150, 16)              0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 150, 16)              32        ['Input_Spec[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 75, 16)               0         ['activation[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 75, 16)               0         ['conv1d_1[0][0]']
#  g1D)
#
#  add (Add)                   (None, 75, 16)               0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 75, 32)               2592      ['add[0][0]']
#
#  batch_normalization_1 (Bat  (None, 75, 32)               128       ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 75, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv1d_3 (Conv1D)           (None, 75, 32)               544       ['add[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 37, 32)               0         ['activation_1[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 37, 32)               0         ['conv1d_3[0][0]']
#  g1D)
#
#  add_1 (Add)                 (None, 37, 32)               0         ['max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 37, 64)               10304     ['add_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 37, 64)               256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 37, 64)               0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv1d_5 (Conv1D)           (None, 37, 64)               2112      ['add_1[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 18, 64)               0         ['activation_2[0][0]']
#  g1D)
#
#  max_pooling1d_5 (MaxPoolin  (None, 18, 64)               0         ['conv1d_5[0][0]']
#  g1D)
#
#  add_2 (Add)                 (None, 18, 64)               0         ['max_pooling1d_4[0][0]',
#                                                                      'max_pooling1d_5[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 18, 128)              41088     ['add_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 18, 128)              512       ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 18, 128)              0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv1d_7 (Conv1D)           (None, 18, 128)              8320      ['add_2[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 9, 128)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_7 (MaxPoolin  (None, 9, 128)               0         ['conv1d_7[0][0]']
#  g1D)
#
#  add_3 (Add)                 (None, 9, 128)               0         ['max_pooling1d_6[0][0]',
#                                                                      'max_pooling1d_7[0][0]']
#
#  flatten (Flatten)           (None, 1152)                 0         ['add_3[0][0]']
#
#  dense (Dense)               (None, 512)                  590336    ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  131328    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  Output_Classes (Dense)      (None, 6)                    1542      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 789254 (3.01 MB)
# Trainable params: 788774 (3.01 MB)
# Non-trainable params: 480 (1.88 KB)
# __________________________________________________________________________________________________

# %%
n_sample = [ngalaxy, nsnia, nsnibc, nsnii, ntde, nkn]
weights = np.max(n_sample) / n_sample
class_weight = {}
for i in range(len(weights)):
    class_weight[i] = weights[i]
class_weight
# Out:
# {0: 4.189595830465139,
#  1: 2.9647877522616564,
#  2: 1.430288380837278,
#  3: 1.0,
#  4: 190.19642857142858,
#  5: 4.761819604336649}

# %%
x.shape, y.shape
# Out:
# ((106101, 150, 1), (106101, 6))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 2)
len(x_test)
# Out:
# 21221

# %%
print(np.sum(y_test[:,4]))
print(np.sum(y_train[:,4]))
batch = 30
epoch = 200
# Out:
# 42.0
# 182.0

# %%
batch = 30
epoch = 180

from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',      # Monitors the validation loss
    factor=0.5,              # Reduces the learning rate by 3/4 when triggered
    patience=5,              # Waits 5 epochs with no improvement before reducing LR
    min_lr=1e-6,             # Sets the minimum learning rate to prevent it from going too low
    verbose=1                # Enables verbose mode to log the adjustments
)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=40)
mc = ModelCheckpoint('b{}_e{}_d5_gap_sntdekn.keras'.format(batch, epoch), monitor='val_loss', mode='min', verbose=1, save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=batch, epochs=epoch, validation_data=(x_test, y_test), shuffle=True, verbose=True, callbacks=[es, mc, reduce_lr], class_weight=class_weight)
# Out:
# Epoch 1/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 7.6680 - accuracy: 0.2429
# Epoch 1: val_loss improved from inf to 4.21259, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 26s 8ms/step - loss: 7.6659 - accuracy: 0.2430 - val_loss: 4.2126 - val_accuracy: 0.3709 - lr: 2.1544e-04
# Epoch 2/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 6.1890 - accuracy: 0.3075
# Epoch 2: val_loss improved from 4.21259 to 3.74504, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 6.1889 - accuracy: 0.3075 - val_loss: 3.7450 - val_accuracy: 0.3906 - lr: 2.1544e-04
# Epoch 3/180
# 2830/2830 [==============================] - ETA: 0s - loss: 5.3210 - accuracy: 0.3485
# Epoch 3: val_loss improved from 3.74504 to 3.26833, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 5.3210 - accuracy: 0.3485 - val_loss: 3.2683 - val_accuracy: 0.4239 - lr: 2.1544e-04
# Epoch 4/180
# 2830/2830 [==============================] - ETA: 0s - loss: 4.6993 - accuracy: 0.3810
# Epoch 4: val_loss improved from 3.26833 to 2.84819, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 4.6993 - accuracy: 0.3810 - val_loss: 2.8482 - val_accuracy: 0.4400 - lr: 2.1544e-04
# Epoch 5/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 4.2593 - accuracy: 0.4034
# Epoch 5: val_loss did not improve from 2.84819
# 2830/2830 [==============================] - 21s 8ms/step - loss: 4.2590 - accuracy: 0.4033 - val_loss: 2.9166 - val_accuracy: 0.3338 - lr: 2.1544e-04
# Epoch 6/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 3.8990 - accuracy: 0.4351
# Epoch 6: val_loss improved from 2.84819 to 2.28783, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 3.8988 - accuracy: 0.4351 - val_loss: 2.2878 - val_accuracy: 0.4998 - lr: 2.1544e-04
# Epoch 7/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 3.5323 - accuracy: 0.4717
# Epoch 7: val_loss improved from 2.28783 to 2.16170, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 3.5321 - accuracy: 0.4717 - val_loss: 2.1617 - val_accuracy: 0.4915 - lr: 2.1544e-04
# Epoch 8/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 3.3058 - accuracy: 0.5053
# Epoch 8: val_loss improved from 2.16170 to 1.93532, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 3.3059 - accuracy: 0.5053 - val_loss: 1.9353 - val_accuracy: 0.5679 - lr: 2.1544e-04
# Epoch 9/180
# 2830/2830 [==============================] - ETA: 0s - loss: 3.1897 - accuracy: 0.5252
# Epoch 9: val_loss improved from 1.93532 to 1.93333, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 3.1897 - accuracy: 0.5252 - val_loss: 1.9333 - val_accuracy: 0.5652 - lr: 2.1544e-04
# Epoch 10/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 2.9553 - accuracy: 0.5454
# Epoch 10: val_loss improved from 1.93333 to 1.75334, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 8ms/step - loss: 2.9552 - accuracy: 0.5454 - val_loss: 1.7533 - val_accuracy: 0.5683 - lr: 2.1544e-04
# Epoch 11/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 2.8818 - accuracy: 0.5584
# Epoch 11: val_loss did not improve from 1.75334
# 2830/2830 [==============================] - 21s 8ms/step - loss: 2.8817 - accuracy: 0.5584 - val_loss: 1.9834 - val_accuracy: 0.4830 - lr: 2.1544e-04
# Epoch 12/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 2.7450 - accuracy: 0.5734
# Epoch 12: val_loss improved from 1.75334 to 1.64925, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 2.7447 - accuracy: 0.5735 - val_loss: 1.6493 - val_accuracy: 0.6004 - lr: 2.1544e-04
# Epoch 13/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 2.6755 - accuracy: 0.5830
# Epoch 13: val_loss did not improve from 1.64925
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.6759 - accuracy: 0.5830 - val_loss: 1.7882 - val_accuracy: 0.5682 - lr: 2.1544e-04
# Epoch 14/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 2.6296 - accuracy: 0.5894
# Epoch 14: val_loss did not improve from 1.64925
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.6294 - accuracy: 0.5893 - val_loss: 1.8115 - val_accuracy: 0.5571 - lr: 2.1544e-04
# Epoch 15/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 2.5398 - accuracy: 0.5969
# Epoch 15: val_loss did not improve from 1.64925
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.5398 - accuracy: 0.5969 - val_loss: 1.6835 - val_accuracy: 0.5676 - lr: 2.1544e-04
# Epoch 16/180
# 2830/2830 [==============================] - ETA: 0s - loss: 2.4588 - accuracy: 0.6092
# Epoch 16: val_loss improved from 1.64925 to 1.44001, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.4588 - accuracy: 0.6092 - val_loss: 1.4400 - val_accuracy: 0.6484 - lr: 2.1544e-04
# Epoch 17/180
# 2830/2830 [==============================] - ETA: 0s - loss: 2.4594 - accuracy: 0.6106
# Epoch 17: val_loss did not improve from 1.44001
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.4594 - accuracy: 0.6106 - val_loss: 1.5013 - val_accuracy: 0.6112 - lr: 2.1544e-04
# Epoch 18/180
# 2828/2830 [============================>.] - ETA: 0s - loss: 2.4756 - accuracy: 0.6104
# Epoch 18: val_loss did not improve from 1.44001
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.4757 - accuracy: 0.6104 - val_loss: 1.6893 - val_accuracy: 0.5750 - lr: 2.1544e-04
# Epoch 19/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 2.3149 - accuracy: 0.6282
# Epoch 19: val_loss did not improve from 1.44001
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.3153 - accuracy: 0.6283 - val_loss: 2.2396 - val_accuracy: 0.4221 - lr: 2.1544e-04
# Epoch 20/180
# 2828/2830 [============================>.] - ETA: 0s - loss: 2.3094 - accuracy: 0.6298
# Epoch 20: val_loss did not improve from 1.44001
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.3095 - accuracy: 0.6298 - val_loss: 1.5221 - val_accuracy: 0.5974 - lr: 2.1544e-04
# Epoch 21/180
# 2830/2830 [==============================] - ETA: 0s - loss: 2.3144 - accuracy: 0.6295
# Epoch 21: val_loss did not improve from 1.44001
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010772173118311912.
# 2830/2830 [==============================] - 21s 7ms/step - loss: 2.3144 - accuracy: 0.6295 - val_loss: 1.5871 - val_accuracy: 0.5835 - lr: 2.1544e-04
# Epoch 22/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 2.1433 - accuracy: 0.6502
# Epoch 22: val_loss improved from 1.44001 to 1.27532, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 2.1431 - accuracy: 0.6503 - val_loss: 1.2753 - val_accuracy: 0.6722 - lr: 1.0772e-04
# Epoch 23/180
# 2830/2830 [==============================] - ETA: 0s - loss: 2.1136 - accuracy: 0.6570
# Epoch 23: val_loss improved from 1.27532 to 1.27143, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 8ms/step - loss: 2.1136 - accuracy: 0.6570 - val_loss: 1.2714 - val_accuracy: 0.6698 - lr: 1.0772e-04
# Epoch 24/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 2.0109 - accuracy: 0.6673
# Epoch 24: val_loss did not improve from 1.27143
# 2830/2830 [==============================] - 21s 8ms/step - loss: 2.0103 - accuracy: 0.6674 - val_loss: 1.3123 - val_accuracy: 0.6593 - lr: 1.0772e-04
# Epoch 25/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.9731 - accuracy: 0.6734
# Epoch 25: val_loss improved from 1.27143 to 1.22610, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.9732 - accuracy: 0.6735 - val_loss: 1.2261 - val_accuracy: 0.6715 - lr: 1.0772e-04
# Epoch 26/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 1.9420 - accuracy: 0.6767
# Epoch 26: val_loss did not improve from 1.22610
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.9423 - accuracy: 0.6766 - val_loss: 1.2800 - val_accuracy: 0.6489 - lr: 1.0772e-04
# Epoch 27/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 1.9404 - accuracy: 0.6766
# Epoch 27: val_loss did not improve from 1.22610
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.9404 - accuracy: 0.6766 - val_loss: 1.2799 - val_accuracy: 0.6577 - lr: 1.0772e-04
# Epoch 28/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 1.8933 - accuracy: 0.6836
# Epoch 28: val_loss did not improve from 1.22610
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.8930 - accuracy: 0.6836 - val_loss: 1.2963 - val_accuracy: 0.6521 - lr: 1.0772e-04
# Epoch 29/180
# 2828/2830 [============================>.] - ETA: 0s - loss: 1.9004 - accuracy: 0.6851
# Epoch 29: val_loss did not improve from 1.22610
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.9004 - accuracy: 0.6850 - val_loss: 1.3658 - val_accuracy: 0.6173 - lr: 1.0772e-04
# Epoch 30/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.8674 - accuracy: 0.6858
# Epoch 30: val_loss improved from 1.22610 to 1.15055, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.8676 - accuracy: 0.6857 - val_loss: 1.1505 - val_accuracy: 0.7026 - lr: 1.0772e-04
# Epoch 31/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 1.8140 - accuracy: 0.6921
# Epoch 31: val_loss did not improve from 1.15055
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.8157 - accuracy: 0.6920 - val_loss: 1.2710 - val_accuracy: 0.6387 - lr: 1.0772e-04
# Epoch 32/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.8911 - accuracy: 0.6852
# Epoch 32: val_loss did not improve from 1.15055
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.8912 - accuracy: 0.6851 - val_loss: 1.9151 - val_accuracy: 0.4605 - lr: 1.0772e-04
# Epoch 33/180
# 2830/2830 [==============================] - ETA: 0s - loss: 1.8025 - accuracy: 0.6930
# Epoch 33: val_loss did not improve from 1.15055
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.8025 - accuracy: 0.6930 - val_loss: 1.2701 - val_accuracy: 0.6450 - lr: 1.0772e-04
# Epoch 34/180
# 2830/2830 [==============================] - ETA: 0s - loss: 1.7998 - accuracy: 0.6923
# Epoch 34: val_loss did not improve from 1.15055
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.7998 - accuracy: 0.6923 - val_loss: 1.1766 - val_accuracy: 0.6867 - lr: 1.0772e-04
# Epoch 35/180
# 2828/2830 [============================>.] - ETA: 0s - loss: 1.8080 - accuracy: 0.6913
# Epoch 35: val_loss did not improve from 1.15055
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.386086559155956e-05.
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.8080 - accuracy: 0.6913 - val_loss: 1.2717 - val_accuracy: 0.6560 - lr: 1.0772e-04
# Epoch 36/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 1.7020 - accuracy: 0.7103
# Epoch 36: val_loss did not improve from 1.15055
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.7016 - accuracy: 0.7104 - val_loss: 1.1871 - val_accuracy: 0.6752 - lr: 5.3861e-05
# Epoch 37/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 1.6370 - accuracy: 0.7177
# Epoch 37: val_loss improved from 1.15055 to 1.14017, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.6369 - accuracy: 0.7177 - val_loss: 1.1402 - val_accuracy: 0.6880 - lr: 5.3861e-05
# Epoch 38/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 1.6318 - accuracy: 0.7179
# Epoch 38: val_loss did not improve from 1.14017
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.6315 - accuracy: 0.7179 - val_loss: 1.1838 - val_accuracy: 0.6625 - lr: 5.3861e-05
# Epoch 39/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 1.5930 - accuracy: 0.7238
# Epoch 39: val_loss improved from 1.14017 to 1.11679, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5928 - accuracy: 0.7238 - val_loss: 1.1168 - val_accuracy: 0.6948 - lr: 5.3861e-05
# Epoch 40/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.5945 - accuracy: 0.7260
# Epoch 40: val_loss improved from 1.11679 to 1.08671, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.5942 - accuracy: 0.7260 - val_loss: 1.0867 - val_accuracy: 0.7010 - lr: 5.3861e-05
# Epoch 41/180
# 2828/2830 [============================>.] - ETA: 0s - loss: 1.5544 - accuracy: 0.7289
# Epoch 41: val_loss did not improve from 1.08671
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.5548 - accuracy: 0.7289 - val_loss: 2.4956 - val_accuracy: 0.5670 - lr: 5.3861e-05
# Epoch 42/180
# 2830/2830 [==============================] - ETA: 0s - loss: 1.5442 - accuracy: 0.7291
# Epoch 42: val_loss did not improve from 1.08671
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5442 - accuracy: 0.7291 - val_loss: 1.1386 - val_accuracy: 0.6803 - lr: 5.3861e-05
# Epoch 43/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 1.5334 - accuracy: 0.7338
# Epoch 43: val_loss did not improve from 1.08671
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5330 - accuracy: 0.7338 - val_loss: 1.1860 - val_accuracy: 0.6678 - lr: 5.3861e-05
# Epoch 44/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 1.5247 - accuracy: 0.7340
# Epoch 44: val_loss improved from 1.08671 to 1.04891, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5245 - accuracy: 0.7340 - val_loss: 1.0489 - val_accuracy: 0.7159 - lr: 5.3861e-05
# Epoch 45/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 1.5094 - accuracy: 0.7360
# Epoch 45: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5099 - accuracy: 0.7360 - val_loss: 1.6638 - val_accuracy: 0.5054 - lr: 5.3861e-05
# Epoch 46/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.5024 - accuracy: 0.7342
# Epoch 46: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.5021 - accuracy: 0.7343 - val_loss: 1.0687 - val_accuracy: 0.7060 - lr: 5.3861e-05
# Epoch 47/180
# 2824/2830 [============================>.] - ETA: 0s - loss: 1.4729 - accuracy: 0.7390
# Epoch 47: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 21s 7ms/step - loss: 1.4730 - accuracy: 0.7390 - val_loss: 1.0600 - val_accuracy: 0.7072 - lr: 5.3861e-05
# Epoch 48/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 1.4790 - accuracy: 0.7415
# Epoch 48: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.4790 - accuracy: 0.7416 - val_loss: 1.2270 - val_accuracy: 0.6501 - lr: 5.3861e-05
# Epoch 49/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 1.4597 - accuracy: 0.7433
# Epoch 49: val_loss did not improve from 1.04891
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.693043279577978e-05.
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.4596 - accuracy: 0.7433 - val_loss: 1.0736 - val_accuracy: 0.7122 - lr: 5.3861e-05
# Epoch 50/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 1.4305 - accuracy: 0.7493
# Epoch 50: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.4306 - accuracy: 0.7492 - val_loss: 1.0579 - val_accuracy: 0.7093 - lr: 2.6930e-05
# Epoch 51/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 1.3948 - accuracy: 0.7536
# Epoch 51: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.3949 - accuracy: 0.7537 - val_loss: 1.0999 - val_accuracy: 0.6970 - lr: 2.6930e-05
# Epoch 52/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 1.3720 - accuracy: 0.7566
# Epoch 52: val_loss did not improve from 1.04891
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.3722 - accuracy: 0.7567 - val_loss: 1.0505 - val_accuracy: 0.7075 - lr: 2.6930e-05
# Epoch 53/180
# 2826/2830 [============================>.] - ETA: 0s - loss: 1.3761 - accuracy: 0.7578
# Epoch 53: val_loss improved from 1.04891 to 1.02375, saving model to b30_e180_d5_gap_sntdekn.keras
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.3763 - accuracy: 0.7578 - val_loss: 1.0238 - val_accuracy: 0.7245 - lr: 2.6930e-05
# Epoch 54/180
# 2823/2830 [============================>.] - ETA: 0s - loss: 1.3662 - accuracy: 0.7570
# Epoch 54: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.3660 - accuracy: 0.7570 - val_loss: 1.0579 - val_accuracy: 0.7074 - lr: 2.6930e-05
# Epoch 55/180
# 2827/2830 [============================>.] - ETA: 0s - loss: 1.3538 - accuracy: 0.7599
# Epoch 55: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.3540 - accuracy: 0.7598 - val_loss: 1.0711 - val_accuracy: 0.7068 - lr: 2.6930e-05
# Epoch 56/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 1.3376 - accuracy: 0.7624
# Epoch 56: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 21s 8ms/step - loss: 1.3376 - accuracy: 0.7624 - val_loss: 1.0947 - val_accuracy: 0.6940 - lr: 2.6930e-05
# Epoch 57/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.3259 - accuracy: 0.7648
# Epoch 57: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.3263 - accuracy: 0.7646 - val_loss: 1.0672 - val_accuracy: 0.7067 - lr: 2.6930e-05
# Epoch 58/180
# 2825/2830 [============================>.] - ETA: 0s - loss: 1.3235 - accuracy: 0.7652
# Epoch 58: val_loss did not improve from 1.02375
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.346521639788989e-05.
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.3234 - accuracy: 0.7652 - val_loss: 1.0593 - val_accuracy: 0.7154 - lr: 2.6930e-05
# Epoch 59/180
# 2829/2830 [============================>.] - ETA: 0s - loss: 1.2947 - accuracy: 0.7686
# Epoch 59: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.2947 - accuracy: 0.7686 - val_loss: 1.0618 - val_accuracy: 0.7067 - lr: 1.3465e-05
# Epoch 60/180
# 2830/2830 [==============================] - ETA: 0s - loss: 1.2814 - accuracy: 0.7724
# Epoch 60: val_loss did not improve from 1.02375
# 2830/2830 [==============================] - 22s 8ms/step - loss: 1.2814 - accuracy: 0.7724 - val_loss: 1.0445 - val_accuracy: 0.7142 - lr: 1.3465e-05
# Epoch 61/180
# 2606/2830 [==========================>...] - ETA: 1s - loss: 1.2790 - accuracy: 0.7728

# %%
model = tf.keras.models.load_model('b30_e180_d5_gap_sntdekn.keras')

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5), sharex=True)

nepoch = len(hist.history['loss'])
epochs = np.arange(1, nepoch+1)

ax = axes[0]
ax.plot(epochs, hist.history['accuracy'], label='acc')
ax.plot(epochs, hist.history['val_accuracy'], label='val_acc')
ax.set(xlabel='training epoch',
       ylabel='accuracy',
       xlim=(0, nepoch),
       ylim=(0.,1.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')

ax = axes[1]
ax.plot(epochs, hist.history['loss'], label='loss')
ax.plot(epochs, hist.history['val_loss'], label='val_loss')
ax.set(xlabel='training epoch',
       ylabel='loss',
       xlim=(0, nepoch),
#        ylim=(0.,2.0)
      )
ax.legend(fontsize=12, loc='best')
ax.grid(ls=':')
ax.set_yscale("log")

fig.tight_layout()
plt.savefig('b{}_e{}_accuracy.png'.format(batch, epoch))

# %%
tde_test = np.load("tde_flux_2.npy").reshape(-1, nbins, 1)
tde_test.shape
# Out:
# (27, 150, 1)

# %%
tde_pred = model.predict(tde_test)
plt.hist(tde_pred[:,4])
# Out:
# 1/1 [==============================] - 0s 164ms/step
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  2., 23.]),
#  array([0.99304777, 0.993743  , 0.99443823, 0.99513346, 0.99582869,
#         0.99652386, 0.99721909, 0.99791431, 0.99860954, 0.99930477,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
[labels[np.argmax(i)] for i in tde_pred]
# Out:
# ['TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE',
#  'TDE']

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# 664/664 [==============================] - 1s 1ms/step
# array([[5.01593611e-09, 9.99884963e-01, 1.12530775e-04, 2.54812858e-06,
#         2.98245586e-13, 4.51787783e-12],
#        [8.55493069e-01, 9.75211710e-03, 9.02851075e-02, 4.43028100e-02,
#         1.25338775e-04, 4.16068870e-05],
#        [1.76750459e-02, 6.32119831e-03, 3.51608321e-02, 9.40762520e-01,
#         2.11762176e-06, 7.83263167e-05],
#        ...,
#        [7.83306062e-01, 4.21341788e-03, 4.28935513e-02, 1.69581905e-01,
#         5.15497550e-06, 2.38096898e-09],
#        [9.34119523e-01, 1.45880403e-02, 3.70853543e-02, 1.42007004e-02,
#         1.29437433e-06, 5.01744626e-06],
#        [2.01253757e-01, 2.42553860e-01, 6.56735003e-02, 4.86881346e-01,
#         1.02240025e-04, 3.53529258e-03]], dtype=float32)

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True, sharey=True)

all_fpr = None
all_tpr = None

fpr = dict()
tpr = dict()
pre = dict()
rec = dict()
for i in range(ntypes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:,i], y_pred[:,i])        
    roc_auc = auc(fpr[i], tpr[i])
    
    ax = axes[0]
    ax.plot(fpr[i], tpr[i], label='{}; AUC = {:.2f}'.format(labels[i], roc_auc))
    ax.grid(ls=':')
    
    pre[i], rec[i], _ = precision_recall_curve(y_test[:,i], y_pred[:,i])
    
    ax = axes[1]
    ax.plot(rec[i], pre[i])

all_fpr = np.unique(np.concatenate([fpr[i] for i in range(ntypes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(ntypes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
fpr['macro'] = all_fpr
tpr['macro'] = mean_tpr / ntypes
fpr['macro'] = np.insert(fpr['macro'], 0, 0)
tpr['macro'] = np.insert(tpr['macro'], 0, 0)
roc_auc_macro = auc(fpr['macro'], tpr['macro'])
        
ax = axes[0]
ax.plot(fpr['macro'], tpr['macro'], lw=3, ls='--', color='k',
        label='cat. avg. ROC\nAUC = {:.2f}'.format(roc_auc_macro))
ax.set(xlim=(-0.01,1.01), xlabel='FPR = FP / (FP + TN)',
       ylim=(-0.01,1.01), ylabel='recall (TPR) = TP / (TP + FN)',
       title='ROC: AUC = {:.3f}'.format(roc_auc_macro),
       aspect='equal')
ax.legend(fontsize=10, loc='lower right')

ax = axes[1]
pre['micro'], rec['micro'], _ = precision_recall_curve(y_test.ravel(), y_pred.ravel())
ax.plot(rec['micro'], pre['micro'], lw=3, ls='--', color='k')

f_scores = np.linspace(0.1, 0.9, num=5)
for f_score in f_scores:
    x_ = np.linspace(0.01, 1)
    y_ = f_score * x_ / (2 * x_ - f_score)
    l, = plt.plot(x_[y_ >= 0], y_[y_ >= 0], color='k', ls='--', alpha=0.3)
    ax.annotate(' $F_{{1}}={0:0.1f}$'.format(f_score), xy=(1.01, y_[45]-0.02),
                fontsize=12, alpha=0.8)
ax.grid(ls=':')
ax.set(xlabel='recall (TPR) = TP / (TP + FN)',
       ylabel='precision = TP / (TP + FP)',
       title='Average precision = {:.3f}'.format(average_precision_score(y_test, y_pred)),
       aspect='equal')

fig.tight_layout()
plt.savefig('b{}_e{}_metrics.png'.format(batch, epoch))

# %%
from sklearn.metrics import confusion_matrix

# In the multilabel classifier, test that the maximum of the
# output matrix of values matches.
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cmnorm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
fig, ax = plt.subplots(1,1, figsize=(10,9))

im = ax.imshow(cmnorm, cmap='Blues', vmin=0, vmax=1)
cb = ax.figure.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
cb.set_label('correct label fraction')

ax.set(aspect='equal',
       xlabel='predicted label',
       xticks=np.arange(cm.shape[1]),
       xticklabels=labels,
       ylabel='true label',
       yticks=np.arange(cm.shape[1]),
       yticklabels=labels)

thresh = 0.5*cm.max()
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, '{:.3f}\n({:d})'.format(cmnorm[i,j], cm[i,j]),
                ha='center', va='center',
                color='black' if cm[i,j] < thresh else 'white')

plt.tight_layout()
plt.savefig('b{}_e{}_matrix.png'.format(batch, epoch))
